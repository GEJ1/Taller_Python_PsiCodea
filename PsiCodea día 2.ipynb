# %% [markdown]
# Listita de cosas para hacer:
# *   Limpiar datos para que no haya tantas columnas - **DONE**
# *   Armar ejemplitos de cosas con un toy data
# *   Agregar descripción del experimento (podemos meter el link y hacer la prueba en vivo)
# *   Explicar un poco más de las librerías?
# *   Agregar links a documentación de las librerías
# *   Mostrar como descargar los datos + los gráficos

# %% [markdown]
# # Importando las librerías
#
# * Importar una librería es como ir a buscar la caja de herramientas y ponerla sobre una mesa de trabajo lista para que su contenido sea utilizado.
#
# * Las librerías (del inglés *library* que significa biblioteca pero nadie les dice así) son bloques de código que están agrupados para cumplir una función o conjunto de funciones.
#
# * En este caso vamos a hacer uso de las siguientes:
#   * **Numpy**: Librería para álgebra lineal. Nos permitirá, entre otras cosas, utilizar arreglos (*arrays*) y por lo tanto potenciar nuetras capacidades matemáticas.
#   * **Pandas** : Para trabajar con *data frames*, un tipo de dato similar a una tabla de excel. Necesita a Numpy para funcionar.
#   * **matplotlib**: Para realizar gráficos y visualizaciones en general.
#   * **scipy** : Para análisis estadístico.

# %%
# Sintaxis para importar librerias, el "as" es una manera de definirla con un nombre mas sencillo, pero no es obligatorio.
# Normalmente habría que instalarlas en nuestra compu, pero vienen ya instaladas en las compus donde Google Colab está corriendo nuestro código.
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy import stats

# %%
# @title Video para musicalizar el aprendizaje y mostrar que en Google Colab se puede insertar prácticamente cualquier tipo de contenido. Dale doble click a esta celda para ver el código.

from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/D2yymMhjRu8" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/D2yymMhjRu8" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# # Numpy en 5 minutos
#
#  * Nos proporciona un nuevo tipo de dato que se llama arreglo o *array* que posee las siguientes características:
#
#  1. Puede guardar elementos como en una lista y la manera de acceder a ellos es ...)
#  2. Permite realizar operaciones entre arreglos, cosa que en una lista no es posible.
#  2. Es mucho más rápido.
#  3. Es la base de todo el ecosistema de librerías científicas de Python.
#  4. Evita que usemos MATLAB    <img width="20" height="auto" src="https://cdn.shopify.com/s/files/1/1061/1924/products/Upside-Down_Face_Emoji_4dbbbd80-eb60-4c91-9642-83368692e361_large.png?v=1571606036
# ">
# <center>
# <img width="500" height="auto" src="https://i.stack.imgur.com/Tbe9W.png">
# <p>Fuente: https://medium.com/@mo000007/numpy-for-beginners-19d64e164df6 </p>
# </center>

# %%
# Creando arrays

# Array de 1 dimensión en numpy
# array_1D = np.array([7,2,9,0])
# print(array_1D)

# Array 2D en numpy
# array_2D = np.array([[5.2, 3.0, 4.5], [9.1, 0.1,0.3]])
# print(array_2D)

# Creando arrays de ceros de la dimension que uno quiera
# zeros = np.zeros((2,3,2)) 
# print(zeros)

# Creando arrays de unos de la dimension que uno quiera
ones = np.ones((4,2)) 
print(ones)

# %%
# Tamaño del array en formato filas,columnas
array_2D.shape
# Out:
# (2, 3)

# %%
# Algunas operaciones basicas

# Multiplicacion por un escalar
# fives = ones*5
# print(fives)

# multiplicacion de matrices
fours = ones*4
fives * fours
# Out:
# array([[20., 20.],
#        [20., 20.],
#        [20., 20.],
#        [20., 20.]])

# %% [markdown]
# # Manos a la data!
#
# Vamos a trabajar con los datos de un experimento online muy sencillo que involucra percepción y tiempos de reaccción.
#
# * La tarea consistía en presionar la tecla j si aparecía en la pantalla un círculo naranja y la tecla f si aparecía un círculo azul. Los estímulos aparecían solo durante una fracción de segundo.
#
# <center>
# <img width="500" height="auto" src="https://miro.medium.com/max/729/1*KBXJ2QKaHUgrxLZaHxuksA.png">
# <p>Fuente: https://www.jspsych.org/tutorials/rt-task/</p>
# </center>
#
# * Los datos que van a estar ordenados de la siguiente manera:
#   * Cada fila corresponde a la presentación de un círculo
#   * Tendremos las columnas:

# %% [markdown]
# # Montamos nuestro drive en Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Cargamos nuestro archivo
# ### Podes descargarlo de Github desde [acá](https://github.com/GEJ1/Tutoriales_jsPsych/blob/master/go-no-go.csv)
#
# ### O si no están muy familiarizados con git pueden bajar el .zip desde [acá](https://minhaskamal.github.io/DownGit/#/home?url=https:%2F%2Fgithub.com%2FGEJ1%2FTutoriales_jsPsych%2Fblob%2Fmaster%2Fgo-no-go.csv), pero no se olviden de descompromirlo porque lo necesitamos en formato .csv

# %%
# Creamos nuestro DataFrame con los datos de nuestro experimento
df = pd.read_csv('/content/drive/MyDrive/datos_de_mi_experimento/data_psicodea_dia2.csv')

# %%
#Para cargarlo directamente desde github
url = 'https://raw.githubusercontent.com/GEJ1/Tutoriales_jsPsych/master/go-no-go.csv'
df = pd.read_csv(url)

# %%
# Dimensiones descriptas en formato (filas, columnas)
df.shape
# Out:
# (40, 5)

# %%
#Miramos los primeros 5 valores
df
# Out:
#     trial_index       rt          stimulus test_part correct
# 0             0      NaN  cruz_de_fijacion  fixation     NaN
# 1             1  466.525    img/orange.png      test    True
# 2             2      NaN  cruz_de_fijacion  fixation     NaN
# 3             3  464.150      img/blue.png      test   False
# 4             4      NaN  cruz_de_fijacion  fixation     NaN
# 5             5  617.920      img/blue.png      test    True
# 6             6      NaN  cruz_de_fijacion  fixation     NaN
# 7             7  487.390    img/orange.png      test    True
# 8             8      NaN  cruz_de_fijacion  fixation     NaN
# 9             9  355.080    img/orange.png      test    True
# 10           10      NaN  cruz_de_fijacion  fixation     NaN
# 11           11  444.515      img/blue.png      test    True
# 12           12      NaN  cruz_de_fijacion  fixation     NaN
# 13           13  936.490      img/blue.png      test    True
# 14           14      NaN  cruz_de_fijacion  fixation     NaN
# 15           15  431.135    img/orange.png      test   False
# 16           16      NaN  cruz_de_fijacion  fixation     NaN
# 17           17  472.015    img/orange.png      test    True
# 18           18      NaN  cruz_de_fijacion  fixation     NaN
# 19           19  572.165      img/blue.png      test    True
# 20           20      NaN  cruz_de_fijacion  fixation     NaN
# 21           21  466.525    img/orange.png      test    True
# 22           22      NaN  cruz_de_fijacion  fixation     NaN
# 23           23  464.150      img/blue.png      test    True
# 24           24      NaN  cruz_de_fijacion  fixation     NaN
# 25           25  617.920      img/blue.png      test    True
# 26           26      NaN  cruz_de_fijacion  fixation     NaN
# 27           27  487.390    img/orange.png      test    True
# 28           28      NaN  cruz_de_fijacion  fixation     NaN
# 29           29  355.080    img/orange.png      test    True
# 30           30      NaN  cruz_de_fijacion  fixation     NaN
# 31           31  444.515      img/blue.png      test    True
# 32           32      NaN  cruz_de_fijacion  fixation     NaN
# 33           33  936.490      img/blue.png      test   False
# 34           34      NaN  cruz_de_fijacion  fixation     NaN
# 35           35  431.135    img/orange.png      test   False
# 36           36      NaN  cruz_de_fijacion  fixation     NaN
# 37           37  472.015    img/orange.png      test    True
# 38           38      NaN  cruz_de_fijacion  fixation     NaN
# 39           39  572.165      img/blue.png      test    True

# %%
#Comando para estadísticas basicas
df.describe()
# Out:
#        trial_index          rt
# count    40.000000   20.000000
# mean     19.500000  524.738500
# std      11.690452  157.509315
# min       0.000000  355.080000
# 25%       9.750000  444.515000
# 50%      19.500000  469.270000
# 75%      29.250000  572.165000
# max      39.000000  936.490000

# %%
# Obtenemos información, en particular nos interesa conocer el tipo de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   trial_index  40 non-null     int64
#  1   rt           20 non-null     float64
#  2   stimulus     40 non-null     object
#  3   test_part    40 non-null     object
#  4   correct      20 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.7+ KB

# %%
# Tambien lo podríamos haber obtenido así individualmente

print(df['trial_index'].dtypes)
print(df['rt'].dtypes)
print(df['stimulus'].dtypes)
print(df['test_part'].dtypes)
print(df['correct'].dtypes)
# Out:
# int64
# float64
# object
# object
# object

# %%
# Filtro los tiempos de respuesta para estímulos naranjas y creo una nueva columna para ellos
df['rt_naranjas'] = df[df['stimulus'].str.contains("orange")]['rt']

# %%
# Filtro los tiempos de respuesta para estímulos azules y creo una nueva columna para ellos
df['rt_azules'] = df[df['stimulus'].str.contains("blue")]['rt']

# %%
# Revisamos
df
# Out:
#     trial_index       rt          stimulus  ... correct rt_naranjas  rt_azules
# 0             0      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 1             1  466.525    img/orange.png  ...    True     466.525        NaN
# 2             2      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 3             3  464.150      img/blue.png  ...   False         NaN    464.150
# 4             4      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 5             5  617.920      img/blue.png  ...    True         NaN    617.920
# 6             6      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 7             7  487.390    img/orange.png  ...    True     487.390        NaN
# 8             8      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 9             9  355.080    img/orange.png  ...    True     355.080        NaN
# 10           10      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 11           11  444.515      img/blue.png  ...    True         NaN    444.515
# 12           12      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 13           13  936.490      img/blue.png  ...    True         NaN    936.490
# 14           14      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 15           15  431.135    img/orange.png  ...   False     431.135        NaN
# 16           16      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 17           17  472.015    img/orange.png  ...    True     472.015        NaN
# 18           18      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 19           19  572.165      img/blue.png  ...    True         NaN    572.165
# 20           20      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 21           21  466.525    img/orange.png  ...    True     466.525        NaN
# 22           22      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 23           23  464.150      img/blue.png  ...    True         NaN    464.150
# 24           24      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 25           25  617.920      img/blue.png  ...    True         NaN    617.920
# 26           26      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 27           27  487.390    img/orange.png  ...    True     487.390        NaN
# 28           28      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 29           29  355.080    img/orange.png  ...    True     355.080        NaN
# 30           30      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 31           31  444.515      img/blue.png  ...    True         NaN    444.515
# 32           32      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 33           33  936.490      img/blue.png  ...   False         NaN    936.490
# 34           34      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 35           35  431.135    img/orange.png  ...   False     431.135        NaN
# 36           36      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 37           37  472.015    img/orange.png  ...    True     472.015        NaN
# 38           38      NaN  cruz_de_fijacion  ...     NaN         NaN        NaN
# 39           39  572.165      img/blue.png  ...    True         NaN    572.165
#
# [40 rows x 7 columns]

# %%
# Preparo los naranjas y azules para utilizarlos eliminando los NaN y
# asegurándome que sean los valores sean tipo numérico.
naranjas = df['rt_naranjas'].dropna()
azules = df['rt_azules'].dropna()

# %%
# Plot para los azules
fig2, ax2 = plt.subplots()
ax2.set_title('boxplot')
ax2.boxplot(azules)

plt.show()

# %%
fig2, ax2 = plt.subplots()
ax2.set_title('boxplot')
ax2.boxplot(naranjas)

plt.show()

# %%
azules
# Out:
# 3     464.150
# 5     617.920
# 11    444.515
# 13    936.490
# 19    572.165
# 23    464.150
# 25    617.920
# 31    444.515
# 33    936.490
# 39    572.165
# Name: rt_azules, dtype: float64

# %%
data = [azules,naranjas]
fig1, ax = plt.subplots()
ax.set_title('Tiempo de reacción')
ax.boxplot(data)

# etiqueta eje x 
ax.set_xticklabels(['azules', 'naranjas'])

# Estilo y colores de las cajas
bp = ax.boxplot(data, patch_artist = True) 
colors = ['#0000FF',  '#f44611'] 
  
for patch, color in zip(bp['boxes'], colors): 
    patch.set_facecolor(color) 

# Estilos de los puntos 
for flier in bp['fliers']: 
    flier.set(marker ='x', 
              color ='#e7298a', 
              alpha = 0.5) 
    
# Color y grosor de las líneas que marcan las medianas 
for median in bp['medians']: 
    median.set(color ='black', 
               linewidth = 3) 
# Mostrar el gráfico
plt.show()

# %%
# Hacemos un  t-test de naranjas vs. azules

stats.ttest_ind(naranjas,azules)
# Out:
# Ttest_indResult(statistic=-2.694702384433896, pvalue=0.014817394406916819)
